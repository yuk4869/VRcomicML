# %%
import pycaret
print(pycaret.__version__)
# Out:
# 2.3.10

# %%
import warnings
# 不要な警告文非表示
warnings.filterwarnings("ignore")
from pycaret.classification import *
import pandas as pd

eye_data = pd.DataFrame()
temp = pd.read_csv('data/raw/23/Chapter1.csv', encoding="ms932", sep=",")
eye_data = pd.concat([eye_data, temp])

# %%
eye_data.head()
# Out:
#    TimeStamp  IsAnnotation  Page  Panel  LeftDiameter  \
# 0   9.656321         False     1     -1      4.987259
# 1   9.708792         False     1     -1      4.071945
# 2  10.241330         False     1     -1      4.981674
# 3  10.247370         False     1     -1      4.999908
# 4  10.253310         False     1     -1      5.008057
#
#    LeftDisplaceNormalizedX  LeftDisplaceNormalizedY  LeftOriginPosX  \
# 0                 0.470837                 0.513666        33.35413
# 1                 0.458934                 0.533783        33.45250
# 2                 0.486479                 0.517612        33.14964
# 3                 0.486307                 0.517439        33.14882
# 4                 0.485812                 0.517439        33.15047
#
#    LeftOriginPosY  LeftOriginPosZ  LeftOpenness  LeftGazeDirectionX  \
# 0        5.463150       -38.56717      1.000000           -0.029694
# 1        5.640015       -38.97659      0.813237            0.027740
# ...

# %%
ans_data = pd.DataFrame()
ans_temp = pd.read_csv('data/raw/23/AnswerChapter1.csv', encoding="ms932", sep=",")
ans_data = pd.concat([ans_data, ans_temp])
ans_data.head()
# Out:
#    Page  Panel  IsDifficult  IsUnderStand
# 0     1      1        False         False
# 1     1      2        False         False
# 2     1      3        False         False
# 3     1      4        False         False
# 4     1      5        False         False

# %%
df = pd.merge(eye_data, ans_data, on=["Page", "Panel"])
df.head()
# Out:
#    TimeStamp  IsAnnotation  Page  Panel  LeftDiameter  \
# 0   16.08122         False     1      2     -1.000000
# 1   16.08719         False     1      2      3.554306
# 2   16.09317         False     1      2      3.554306
# 3   16.09916         False     1      2      3.162018
# 4   16.10514         False     1      2      3.162018
#
#    LeftDisplaceNormalizedX  LeftDisplaceNormalizedY  LeftOriginPosX  \
# 0                 0.563431                 0.465777        31.82370
# 1                 0.555529                 0.468840        31.97658
# 2                 0.555529                 0.468840        31.97658
# 3                 0.547111                 0.473551        32.04996
# 4                 0.547111                 0.473551        32.04996
#
#    LeftOriginPosY  LeftOriginPosZ  LeftOpenness  LeftGazeDirectionX  \
# 0        6.146332       -38.84834           1.0            0.000000
# 1        6.071625       -38.82573           1.0           -0.240860
# ...

# %%
exp1 = setup(df, target = "IsDifficult")
# Out:
# <style type="text/css">
# #T_0ea19_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0ea19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ea19_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0ea19_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ea19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ea19_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_0ea19_row0_col1" class="data row0 col1" >7416</td>
#     </tr>
#     <tr>
#       <th id="T_0ea19_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0ea19_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0ea19_row1_col1" class="data row1 col1" >IsDifficult</td>
#     </tr>
#     <tr>
#       <th id="T_0ea19_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_f253e th {
#   text-align: left;
# }
# ...

# %%
model = create_model('svm')
turnd_model = tune_model(model, optimize = 'Accuracy')
# Out:
# <style type="text/css">
# #T_85e26_row10_col0, #T_85e26_row10_col1, #T_85e26_row10_col2, #T_85e26_row10_col3, #T_85e26_row10_col4, #T_85e26_row10_col5, #T_85e26_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_85e26">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85e26_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_85e26_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_85e26_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_85e26_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_85e26_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_85e26_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_85e26_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
evaluate_model(turnd_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
